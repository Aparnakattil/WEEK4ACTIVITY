# %%
#import libraries and load the data to python enviroment
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_excel('churn.xlsx')
df
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
# ...

# %% [markdown]
# 1. Compare churn count with respect to gender.

# %%
sns.countplot(x='gender',data=df,hue='Churn')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %% [markdown]
# 2. Find out how many female senior citizens there in the dataset

# %%
df[(df['gender']=='Female') &  (df['SeniorCitizen']==1.0)]['SeniorCitizen'].count()
# Out:
# 568

# %%
df2=df[(df['gender']=='Female') &  (df['SeniorCitizen']==1.0)]
sns.countplot(data=df2,x='SeniorCitizen')
# Out:
# <AxesSubplot:xlabel='SeniorCitizen', ylabel='count'>

# %% [markdown]
#  3. Compare 'tenure' with 'Total Charges'

# %%
    
sns.scatterplot(data=df,x='tenure',y='TotalCharges')
plt.title('Tenure Vs Total Charges')
plt.tight_layout()

# %% [markdown]
#  4. Find out which contract is preferred by the senior citizen.

# %%
df3 = df[df['SeniorCitizen']==1.0]
sns.countplot(x='SeniorCitizen',data=df3, hue='Contract')
# Out:
# <AxesSubplot:xlabel='SeniorCitizen', ylabel='count'>

# %% [markdown]
# 5. Comment on your finds on Payment Method?

# %%
#payment method vs frequency
import matplotlib.pyplot as plt
plt.style.use('classic')
plt.hist(df['PaymentMethod'],rwidth=1,color='orange')
plt.title('Histogram of PaymentMethod')
plt.xlabel('PaymentMethod')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#payment method vs senior citizen
sns.countplot(x='SeniorCitizen',data=df,hue='PaymentMethod')
# Out:
# <AxesSubplot:xlabel='SeniorCitizen', ylabel='count'>

# %%
#payment method vs gender
sns.countplot(x='gender',data=df,hue='PaymentMethod')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %% [markdown]
# Findings on payment method
#     * The most preferred payment method is electronic check.
#     *both senior citizen and non senior citizen prefer eleconic check method
#     *while considering gender,both males and females prefer leconic check method
